# %%
from accelforge import Spec, examples
from pathlib import Path

# %%
def get_energy(result):
    """Get total energy in pJ."""
    return float(result.energy())


def get_cycles(result):
    """Get total latency in cycles."""
    return float(result.latency())


def get_component_energy(result, component):
    """Get energy for a specific component."""
    energy = result.energy(per_component=True)
    return float(energy.get(component, 0))

def get_component_cycles(result, component):
    """Get energy for a specific component."""
    latency = result.latency(per_component=True)
    return float(latency.get(component, 0))

# %% [markdown]
# # Pure Accelforge Run

# %%
# spec = Spec.from_yaml(
#     "../arches/tpu_v4i_with_VPU.yaml",
#     "../workloads/C_4/flash_attention_C_4.yaml"
# )
# results = spec.map_workload_to_arch()

# %%
# results

# %%
# print("Total Cycles: ", get_cycles(results))
# print("Total Energy: ", get_energy(results))
# print("MainMemory: ", get_component_energy(results, 'MainMemory'))
# print("GlobalBuffer: ", get_component_energy(results, 'GlobalBuffer'))
# print()
# print("ScalarBuffer: ", get_component_energy(results, 'ScalarBuffer'))
# print("ScalarUnit: ", get_component_energy(results, 'ScalarUnit'))
# print()
# print("VpuBuffer: ", get_component_energy(results, 'VpuBuffer'))
# print("VPU: ", get_component_energy(results, 'VPU'))
# print()
# print("MxuBuffer: ", get_component_energy(results, 'MxuBuffer'))
# print("MXU: ", get_component_energy(results, 'MXU'))

# %% [markdown]
# # P = 1

# %%
# QK
P_1_QK_spec = Spec.from_yaml(
    "../arches/tpu_v4i_with_VPU_QK.yaml",
    "../workloads/C_8_MR/flash_attention_C_8_QK.yaml"
)
P_1_QK_results = P_1_QK_spec.map_workload_to_arch()
# Out:
# Getting energy, latency, and leak power for compone
# Generating jobs:   0%|       | 0/1 [00:00<?, ?it/s]
# Generating pmapping templates for compute ScalarUnit Einsum QK_1: 0it [00:00, ?it/s]
#
# Generating pmapping templates for compute MXU Einsum QK_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute MXU Einsum QK_1: 9it [00:00, 79.68it/s]
# Generating pmapping templates for compute MXU Einsum QK_1: 18it [00:00, 85.06it/s]
# Generating pmapping templates for compute MXU Einsum QK_1: 32it [00:00, 86.49it/s]
# Generating jobs: 100%|█| 1/1 [00:00<00:00,  2.29it/
# Einsum QK_1 has 32 pmapping jobs:
# 	0	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	1	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	2	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	3	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	4	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	5	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	6	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	7	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	8	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	9	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	10	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [K_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	11	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [K_1 in GlobalBuffer] T-m  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	12	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [QK_1 in GlobalBuffer] T-e  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	13	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [QK_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	14	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [K_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	15	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [K_1 in GlobalBuffer] T-m  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	16	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] T-e  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	17	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	18	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	19	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	20	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [Q in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] T-e  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	21	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [Q in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	22	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [QK_1 in GlobalBuffer] T-e  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	23	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [K_1 in GlobalBuffer] T-m  [QK_1 in GlobalBuffer] T-e  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	24	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [K_1 in GlobalBuffer] T-m  [QK_1 in GlobalBuffer] T-e  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	25	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [K_1 in GlobalBuffer] T-m  [QK_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	26	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] T-e  [K_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	27	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-e  T-h  T-m  [Q in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] T-e  [K_1 in GlobalBuffer] T-m  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	28	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [K_1 in GlobalBuffer] T-m  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	29	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [K_1 in GlobalBuffer] T-m  [Q in GlobalBuffer] T-m_chunk  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# 	30	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [Q in GlobalBuffer] T-m_chunk  [K_1 in GlobalBuffer] S-reuse_weight2-e  S-reuse_weight1-m_chunk  [K_1 in MxuBuffer] T-m  [QK_1 in MxuBuffer] T-e  MXU computes QK_1
# 	31	[QK_1 in MainMemory] [Q in MainMemory] [K_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] T-e  [Q in GlobalBuffer] T-m_chunk  [K_1 in GlobalBuffer] T-m  S-reuse_weight2-e  S-reuse_weight1-m_chunk  [QK_1 in MxuBuffer] T-e  [K_1 in MxuBuffer] T-m  MXU computes QK_1
# Total number of pmapping templates: 32
# Not tracking memory GlobalBuffer. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 12.61%
# Not tracking memory MainMemory. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 0.00%
# Not tracking memory MxuBuffer across joining stages. It is never reserved across fused loop iterations.
# Generating pmappings: 100%|█| 32/32 [00:24<00:00,
# Grouping pmappings for QK_1: 100%|█| 1/1 [00:00<00:
# Compressing pmappings: 100%|█| 1/1 [00:00<00:00, 35
# Dirty joining with resource usage <= 1.02× optimal
# Dirty joining with objectives <= 2× optimal
# Dirty pruning pmappings: 100%|█| 1/1 [00:00<00:00,
# Dirty joining uses 100.00% of the pmappings
# Final consolidate: 100%|█| 1/1 [00:00<00:00, 1001.2
# Filtering out pmappings worse than the following:
# 	Total<SEP>energy=1.10e-03
# Final clean join.
# Dirty pruning pmappings: 100%|█| 1/1 [00:00<00:00,
# Dirty joining uses 100.00% of the pmappings
# Filtered 1 -> 1 (100.00% kept) pmappings
# Final consolidate: 100%|█| 1/1 [00:00<00:00, 379.37
# Dirty joining mapping(s) valid & optimal! Returning...

# %%
# QK
P_1_QK_results

# %%
# QK
print("Total Cycles: ", get_cycles(P_1_QK_results))
print("Total Energy: ", get_energy(P_1_QK_results))
print("MainMemory: ", get_component_energy(P_1_QK_results, 'MainMemory'))
print("GlobalBuffer: ", get_component_energy(P_1_QK_results, 'GlobalBuffer'))
print()
print("ScalarBuffer: ", get_component_energy(P_1_QK_results, 'ScalarBuffer'))
print("ScalarUnit: ", get_component_energy(P_1_QK_results, 'ScalarUnit'))
print()
print("VpuBuffer: ", get_component_energy(P_1_QK_results, 'VpuBuffer'))
print("VPU: ", get_component_energy(P_1_QK_results, 'VPU'))
print()
print("MxuBuffer: ", get_component_energy(P_1_QK_results, 'MxuBuffer'))
print("MXU: ", get_component_energy(P_1_QK_results, 'MXU'))
# Out:
# Total Cycles:  2.756461253738962e-05
# Total Energy:  0.0011010254899878709
# MainMemory:  0.0009518435108475387
# GlobalBuffer:  2.280652799900847e-06
#
# ScalarBuffer:  0.0
# ScalarUnit:  0.0
#
# VpuBuffer:  0.0
# VPU:  0.0
#
# MxuBuffer:  0.00014549201859593216
# MXU:  1.409286144e-06

# %%
# SM
P_1_SM_spec = Spec.from_yaml(
    "../arches/tpu_v4i_with_VPU.yaml",
    "../workloads/C_8_MR/flash_attention_C_8_SM.yaml"
)
P_1_SM_results = P_1_SM_spec.map_workload_to_arch()
# Out:
# Getting energy, latency, and leak power for compone
# Generating pmapping templates for compute ScalarUnit Einsum max_1: 10it [00:00, 36.38it/s]/s]
# Generating pmapping templates for compute MXU Einsum max_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute VPU Einsum max_1: 0it [00:00, ?it/s]0:00, 41.58it/s]
# Generating pmapping templates for compute ScalarUnit Einsum sum_1: 16it [00:00, 43.50it/s]
# Generating pmapping templates for compute ScalarUnit Einsum softmax_1: 16it [00:00, 41.90it/s]
# Generating pmapping templates for compute ScalarUnit Einsum exp_1: 16it [00:00, 40.72it/s]
# Generating pmapping templates for compute MXU Einsum sum_1: 0it [00:00, ?it/s]t/s]
# Generating pmapping templates for compute MXU Einsum softmax_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute MXU Einsum exp_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute VPU Einsum sum_1: 0it [00:00, ?it/s]t/s]
# Generating pmapping templates for compute VPU Einsum softmax_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute VPU Einsum exp_1: 0it [00:00, ?it/s]
# Generating jobs: 100%|█| 4/4 [00:01<00:00,  2.68it/
# Einsum max_1 has 10 pmapping jobs:
# 	0	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [max_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes max_1
# 	1	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [max_1 in ScalarBuffer] T-m_chunk  [QK_1 in ScalarBuffer] ScalarUnit computes max_1
# 	2	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [max_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes max_1
# 	3	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [max_1 in ScalarBuffer] T-m_chunk  [QK_1 in ScalarBuffer] ScalarUnit computes max_1
# 	4	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  [max_1 in GlobalBuffer] T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [max_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes max_1
# 	5	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  [max_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [max_1 in ScalarBuffer] T-m_chunk  [QK_1 in ScalarBuffer] ScalarUnit computes max_1
# 	6	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] [max_1 in GlobalBuffer] T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [max_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes max_1
# 	7	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] [max_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [max_1 in ScalarBuffer] T-m_chunk  [QK_1 in ScalarBuffer] ScalarUnit computes max_1
# 	8	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  [max_1 in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [max_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes max_1
# 	9	[max_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  [max_1 in GlobalBuffer] T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [max_1 in ScalarBuffer] T-m_chunk  [QK_1 in ScalarBuffer] ScalarUnit computes max_1
# Einsum exp_1 has 16 pmapping jobs:
# 	0	[QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	1	[QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	2	[QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	3	[QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	4	[QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	5	[QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	6	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	7	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	8	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	9	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	10	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	11	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	12	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	13	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [QK_1 in GlobalBuffer] [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	14	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [QK_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes exp_1
# 	15	[exp_1 in MainMemory] [QK_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] [QK_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [QK_1 in ScalarBuffer] ScalarUnit computes exp_1
# Einsum sum_1 has 16 pmapping jobs:
# 	0	[sum_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	1	[sum_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# 	2	[sum_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  [sum_1 in GlobalBuffer] T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	3	[sum_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  [sum_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# 	4	[sum_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [sum_1 in GlobalBuffer] T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	5	[sum_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [sum_1 in GlobalBuffer] T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# 	6	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	7	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# 	8	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	9	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# 	10	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  [sum_1 in GlobalBuffer] T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	11	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  [sum_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# 	12	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] [sum_1 in GlobalBuffer] T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	13	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] [sum_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# 	14	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  [sum_1 in GlobalBuffer] T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [sum_1 in ScalarBuffer] T-m_chunk  ScalarUnit computes sum_1
# 	15	[sum_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  [sum_1 in GlobalBuffer] T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [sum_1 in ScalarBuffer] T-m_chunk  [exp_1 in ScalarBuffer] ScalarUnit computes sum_1
# Einsum softmax_1 has 16 pmapping jobs:
# 	0	[softmax_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	1	[softmax_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	2	[softmax_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	3	[softmax_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	4	[softmax_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	5	[softmax_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] [exp_1 in GlobalBuffer] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	6	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	7	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	8	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	9	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	10	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	11	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	12	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] [softmax_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	13	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [exp_1 in GlobalBuffer] [softmax_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	14	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [exp_1 in ScalarBuffer] [softmax_1 in ScalarBuffer] ScalarUnit computes softmax_1
# 	15	[softmax_1 in MainMemory] [exp_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] [exp_1 in GlobalBuffer] S-Z-m_chunk  S-Z-m  S-Z-h  S-Z-b  [softmax_1 in ScalarBuffer] [exp_1 in ScalarBuffer] ScalarUnit computes softmax_1
# Total number of pmapping templates: 58
# Not tracking memory GlobalBuffer. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 0.59%
# Not tracking memory MainMemory. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 0.00%
# Not tracking memory ScalarBuffer across joining stages. It is never reserved across fused loop iterations.
# Generating pmappings: 100%|█| 58/58 [00:09<00:00,
# Grouping pmappings for max_1: 100%|█| 1/1 [00:00<00
# Grouping pmappings for exp_1: 100%|█| 5/5 [00:00<00
# Grouping pmappings for sum_1: 100%|█| 6/6 [00:00<00
# Grouping pmappings for softmax_1: 100%|█| 5/5 [00:0
# Compressing pmappings: 100%|█| 4/4 [00:00<00:00, 37
# Dirty joining with resource usage <= 1.02× optimal
# Dirty joining with objectives <= 2× optimal
# Dirty pruning pmappings: 100%|█| 17/17 [00:00<00:00
# Dirty joining uses 100.00% of the pmappings
# Joining pmappings for max_1 <--> exp_1 (2/4): 100%|
# Joining pmappings for exp_1 <--> sum_1 (3/4): 100%|
# Joining pmappings for sum_1 <--> softmax_1 (4/4): 1
# Final consolidate: 100%|█| 6/6 [00:00<00:00, 211.34
# Grouping pmappings: 100%|█| 1/1 [00:00<00:00, 53.95
# Filtering out pmappings worse than the following:
# 	Total<SEP>energy=3.37e-05
# Final clean join.
# Dirty pruning pmappings: 100%|█| 17/17 [00:00<00:00
# Dirty joining uses 100.00% of the pmappings
# Filtered 226 -> 226 (100.00% kept) pmappings
# Joining pmappings for max_1 <--> exp_1 (2/4): 100%|
# Joining pmappings for exp_1 <--> sum_1 (3/4): 100%|
# Joining pmappings for sum_1 <--> softmax_1 (4/4): 1
# Final consolidate: 100%|█| 6/6 [00:00<00:00, 205.93
# Dirty joining mapping(s) valid & optimal! Returning...
# /Users/mayarebholz/6.5930/accelforge/accelforge/mapper/FFM/_join_pmappings/join_pmappings.py:368: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   joined.data[f"Total<SEP>{MAPPING_COLUMN}"] = [

# %%
# SM
P_1_SM_results

# %%
# SM
print("Total Cycles: ", get_cycles(P_1_SM_results))
print("Total Energy: ", get_energy(P_1_SM_results))
print("MainMemory: ", get_component_energy(P_1_SM_results, 'MainMemory'))
print("GlobalBuffer: ", get_component_energy(P_1_SM_results, 'GlobalBuffer'))
print()
print("ScalarBuffer: ", get_component_energy(P_1_SM_results, 'ScalarBuffer'))
print("ScalarUnit: ", get_component_energy(P_1_SM_results, 'ScalarUnit'))
print()
print("VpuBuffer: ", get_component_energy(P_1_SM_results, 'VpuBuffer'))
print("VPU: ", get_component_energy(P_1_SM_results, 'VPU'))
print()
print("MxuBuffer: ", get_component_energy(P_1_SM_results, 'MxuBuffer'))
print("MXU: ", get_component_energy(P_1_SM_results, 'MXU'))
# Out:
# Total Cycles:  3.900952378899092e-06
# Total Energy:  3.372192122578443e-05
# MainMemory:  2.2128864726411734e-05
# GlobalBuffer:  6.4172852489718935e-06
#
# ScalarBuffer:  4.546625581122879e-06
# ScalarUnit:  6.291456e-07
#
# VpuBuffer:  0.0
# VPU:  0.0
#
# MxuBuffer:  0.0
# MXU:  0.0

# %%
# AV
P_1_AV_spec = Spec.from_yaml(
    "../arches/tpu_v4i_with_VPU_AV.yaml",
    "../workloads/C_8_MR/flash_attention_C_8_AV.yaml"
)
P_1_AV_results = P_1_AV_spec.map_workload_to_arch()
# Out:
# Getting energy, latency, and leak power for compone
# Generating jobs:   0%|       | 0/1 [00:00<?, ?it/s]
# Generating pmapping templates for compute ScalarUnit Einsum AV_1: 0it [00:00, ?it/s]
#
# Generating pmapping templates for compute MXU Einsum AV_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute MXU Einsum AV_1: 11it [00:00, 102.30it/s]
# Generating pmapping templates for compute MXU Einsum AV_1: 32it [00:00, 98.26it/s]
#
# Generating pmapping templates for compute VPU Einsum AV_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute VPU Einsum AV_1: 11it [00:00, 107.12it/s]
# Generating pmapping templates for compute VPU Einsum AV_1: 32it [00:00, 67.01it/s]
# Generating jobs: 100%|█| 1/1 [00:00<00:00,  1.13it/
# Einsum AV_1 has 64 pmapping jobs:
# 	0	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	1	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	2	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	3	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	4	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	5	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	6	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	7	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	8	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	9	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	10	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	11	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	12	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	13	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	14	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	15	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	16	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	17	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	18	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	19	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	20	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	21	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	22	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	23	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	24	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	25	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	26	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	27	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	28	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	29	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	30	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] S-reuse_weight2-m_chunk  S-reuse_weight1-e  [AV_1 in MxuBuffer] T-m_chunk  [V_1 in MxuBuffer] T-m  MXU computes AV_1
# 	31	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight2-m_chunk  S-reuse_weight1-e  [V_1 in MxuBuffer] T-m  [AV_1 in MxuBuffer] T-m_chunk  MXU computes AV_1
# 	32	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	33	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	34	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	35	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	36	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	37	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	38	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	39	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	40	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	41	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	42	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	43	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	44	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	45	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	46	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	47	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	48	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	49	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	50	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	51	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	52	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	53	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	54	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	55	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	56	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	57	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  [softmax_1 in GlobalBuffer] T-e  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	58	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	59	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-e  T-h  T-m_chunk  [V_1 in GlobalBuffer] T-m  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	60	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] T-m  S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	61	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [AV_1 in GlobalBuffer] T-m_chunk  [V_1 in GlobalBuffer] S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# 	62	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] S-reuse_weight-e  [AV_1 in VpuBuffer] T-m_chunk  [V_1 in VpuBuffer] T-m  VPU computes AV_1
# 	63	[softmax_1 in MainMemory] [V_1 in MainMemory] [AV_1 in MainMemory] T-b  T-h  T-m  T-m_chunk  [softmax_1 in GlobalBuffer] T-e  [V_1 in GlobalBuffer] T-m  [AV_1 in GlobalBuffer] T-m_chunk  S-reuse_weight-e  [V_1 in VpuBuffer] T-m  [AV_1 in VpuBuffer] T-m_chunk  VPU computes AV_1
# Total number of pmapping templates: 64
# Not tracking memory GlobalBuffer. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 12.61%
# Not tracking memory MainMemory. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 0.00%
# Not tracking memory MxuBuffer across joining stages. It is never reserved across fused loop iterations.
# Not tracking memory VpuBuffer across joining stages. It is never reserved across fused loop iterations.
# Generating pmappings: 100%|█| 64/64 [00:12<00:00,
# Grouping pmappings for AV_1: 100%|█| 1/1 [00:00<00:
# Compressing pmappings: 100%|█| 1/1 [00:00<00:00, 20
# Dirty joining with resource usage <= 1.02× optimal
# Dirty joining with objectives <= 2× optimal
# Dirty pruning pmappings: 100%|█| 1/1 [00:00<00:00,
# Dirty joining uses 100.00% of the pmappings
# Final consolidate: 100%|█| 1/1 [00:00<00:00, 3030.5
# Filtering out pmappings worse than the following:
# 	Total<SEP>energy=1.10e-03
# Final clean join.
# Dirty pruning pmappings: 100%|█| 1/1 [00:00<00:00,
# Dirty joining uses 100.00% of the pmappings
# Filtered 1 -> 1 (100.00% kept) pmappings
# Final consolidate: 100%|█| 1/1 [00:00<00:00, 6052.3
# Dirty joining mapping(s) valid & optimal! Returning...

# %%
# AV
P_1_AV_results

# %%
# AV
print("Total Cycles: ", get_cycles(P_1_AV_results))
print("Total Energy: ", get_energy(P_1_AV_results))
print("MainMemory: ", get_component_energy(P_1_AV_results, 'MainMemory'))
print("MainMemory cycles: ", get_component_cycles(P_1_AV_results, 'MainMemory'))

print("GlobalBuffer: ", get_component_energy(P_1_AV_results, 'GlobalBuffer'))
print()
print("ScalarBuffer: ", get_component_energy(P_1_AV_results, 'ScalarBuffer'))
print("ScalarUnit: ", get_component_energy(P_1_AV_results, 'ScalarUnit'))
print()
print("VpuBuffer: ", get_component_energy(P_1_AV_results, 'VpuBuffer'))
print("VPU: ", get_component_energy(P_1_AV_results, 'VPU'))
print()
print("MxuBuffer: ", get_component_energy(P_1_AV_results, 'MxuBuffer'))
print("MXU: ", get_component_energy(P_1_AV_results, 'MXU'))
print("MXU cycles: ", get_component_cycles(P_1_AV_results, 'MXU'))
# Out:
# Total Cycles:  2.756461253738962e-05
# Total Energy:  0.0010987448393956648
# MainMemory:  0.0009518435237417963
# MainMemory cycles:  2.756461253738962e-05
# GlobalBuffer:  0.0
#
# ScalarBuffer:  0.0
# ScalarUnit:  0.0
#
# VpuBuffer:  0.0
# VPU:  0.0
#
# MxuBuffer:  0.00014549202223391097
# MXU:  1.409286144e-06
# MXU cycles:  9.75238094724773e-07

# %%
# ACC
P_1_ACC_spec = Spec.from_yaml(
    "../arches/tpu_v4i_only_VPU.yaml",
    "../workloads/C_8_MR/flash_attention_C_8_ACC.yaml"
)
P_1_ACC_results = P_1_ACC_spec.map_workload_to_arch()
# Out:
# Getting energy, latency, and leak power for compone
# Generating jobs:   0%|       | 0/1 [00:00<?, ?it/s]
# Generating pmapping templates for compute ScalarUnit Einsum AV_accum_1: 0it [00:00, ?it/s]
#
# Generating pmapping templates for compute VPU Einsum AV_accum_1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute VPU Einsum AV_accum_1: 16it [00:00, 78.65it/s][A
# Generating jobs: 100%|█| 1/1 [00:00<00:00,  3.59it/
# Einsum AV_accum_1 has 16 pmapping jobs:
# 	0	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	1	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_0 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	2	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	3	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_accum_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	4	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_0 in GlobalBuffer] [AV_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	5	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] [AV_0 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	6	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_0 in GlobalBuffer] [AV_accum_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	7	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_accum_1 in GlobalBuffer] [AV_0 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	8	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] [AV_accum_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	9	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_accum_1 in GlobalBuffer] [AV_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	10	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_0 in GlobalBuffer] [AV_1 in GlobalBuffer] [AV_accum_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	11	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_0 in GlobalBuffer] [AV_accum_1 in GlobalBuffer] [AV_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	12	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] [AV_0 in GlobalBuffer] [AV_accum_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	13	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_1 in GlobalBuffer] [AV_accum_1 in GlobalBuffer] [AV_0 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	14	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_accum_1 in GlobalBuffer] [AV_0 in GlobalBuffer] [AV_1 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# 	15	[AV_accum_1 in MainMemory] [AV_1 in MainMemory] [AV_0 in MainMemory] T-b  T-e  T-h  T-m  [AV_accum_1 in GlobalBuffer] [AV_1 in GlobalBuffer] [AV_0 in GlobalBuffer] S-reuse_input-m  S-reuse_input-h  S-reuse_input-e  S-reuse_input-b  [AV_accum_1 in VpuBuffer] VPU computes AV_accum_1
# Total number of pmapping templates: 16
# Not tracking memory GlobalBuffer. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 0.04%
# Not tracking memory MainMemory. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 0.00%
# Not tracking memory VpuBuffer. It is big enough to simultaneously hold every workload tensor that may be stored in it. Max possible usage: 9.38%
# Generating pmappings: 100%|█| 16/16 [00:00<00:00, 2
# Grouping pmappings for AV_accum_1: 100%|█| 1/1 [00:
# Compressing pmappings: 100%|█| 1/1 [00:00<00:00, 18
# Dirty joining with resource usage <= 1.02× optimal
# Dirty joining with objectives <= 2× optimal
# Dirty pruning pmappings: 100%|█| 1/1 [00:00<00:00,
# Dirty joining uses 100.00% of the pmappings
# Final consolidate: 100%|█| 1/1 [00:00<00:00, 1904.7
# Filtering out pmappings worse than the following:
# 	Total<SEP>energy=2.84e-06
# Final clean join.
# Dirty pruning pmappings: 100%|█| 1/1 [00:00<00:00,
# Dirty joining uses 100.00% of the pmappings
# Filtered 1 -> 1 (100.00% kept) pmappings
# Final consolidate: 100%|█| 1/1 [00:00<00:00, 5882.6
# Dirty joining mapping(s) valid & optimal! Returning...

# %%
# ACC
P_1_ACC_results

# %%
# ACC
print("Total Cycles: ", get_cycles(P_1_ACC_results))
print("Total Energy: ", get_energy(P_1_ACC_results))
print("MainMemory: ", get_component_energy(P_1_ACC_results, 'MainMemory'))
print("GlobalBuffer: ", get_component_energy(P_1_ACC_results, 'GlobalBuffer'))
print()
print("ScalarBuffer: ", get_component_energy(P_1_ACC_results, 'ScalarBuffer'))
print("ScalarUnit: ", get_component_energy(P_1_ACC_results, 'ScalarUnit'))
print()
print("VpuBuffer: ", get_component_energy(P_1_ACC_results, 'VpuBuffer'))
print("VPU: ", get_component_energy(P_1_ACC_results, 'VPU'))
print()
print("MxuBuffer: ", get_component_energy(P_1_ACC_results, 'MxuBuffer'))
print("MXU: ", get_component_energy(P_1_ACC_results, 'MXU'))
# Out:
# Total Cycles:  1.2190476184059662e-07
# Total Energy:  2.8405923653402333e-06
# MainMemory:  2.7643084598335315e-06
# GlobalBuffer:  0.0
#
# ScalarBuffer:  0.0
# ScalarUnit:  0.0
#
# VpuBuffer:  7.104102905941545e-08
# VPU:  5.24288e-09
#
# MxuBuffer:  0.0
# MXU:  0.0

# %%
# Gathered Results
print("QK Total Cycles: ", get_cycles(P_1_QK_results))
print("QK Total Energy: ", get_energy(P_1_QK_results))
print("SM Total Cycles: ", get_cycles(P_1_SM_results))
print("SM Total Energy: ", get_energy(P_1_SM_results))
print("AV Total Cycles: ", get_cycles(P_1_AV_results))
print("AV Total Energy: ", get_energy(P_1_AV_results))
print("ACC Total Cycles: ", get_cycles(P_1_ACC_results))
print("ACC Total Energy: ", get_energy(P_1_ACC_results))
# Out:
# QK Total Cycles:  2.756461253738962e-05
# QK Total Energy:  0.0011010254899878709
# SM Total Cycles:  3.900952378899092e-06
# SM Total Energy:  3.372192122578443e-05
# AV Total Cycles:  2.756461253738962e-05
# AV Total Energy:  0.0010987448393956648
# ACC Total Cycles:  1.2190476184059662e-07
# ACC Total Energy:  2.8405923653402333e-06

# %%
# Total Pipeline Results
print("Total Pipeline Cycles: ", 8*(get_cycles(P_1_QK_results)+get_cycles(P_1_SM_results)+get_cycles(P_1_AV_results)+get_cycles(P_1_ACC_results)))
print("Total Pipeline Energy: ", 8*(get_energy(P_1_QK_results)+get_energy(P_1_SM_results)+get_energy(P_1_AV_results)+get_energy(P_1_ACC_results)))
# Out:
# Total Pipeline Cycles:  0.00047321665772415145
# Total Pipeline Energy:  0.017890662743797282

# %% [markdown]
# # P = 2

# %%
# Total Pipeline Cycles
QK_cycles = get_cycles(P_1_QK_results)
QK_SM_cycles = max(get_cycles(P_1_QK_results), get_cycles(P_1_SM_results))
AV_SM_cycles = max(get_cycles(P_1_AV_results), get_cycles(P_1_SM_results))
AV_ACC_cycles = max(get_cycles(P_1_AV_results), get_cycles(P_1_ACC_results))
QK_ACC_cycles = max(get_cycles(P_1_QK_results), get_cycles(P_1_ACC_results))
ACC_cycles = get_cycles(P_1_ACC_results)

P_2_cycles = QK_cycles+4*QK_SM_cycles+4*AV_SM_cycles+4*AV_ACC_cycles+3*QK_ACC_cycles+ACC_cycles

print("Total Pipeline Cycles: ", P_2_cycles)
# Out:
# Total Pipeline Cycles:  0.00044115570536007453

# %%
# Total Pipeline Energy
QK_energy = get_energy(P_1_QK_results)
QK_SM_energy = max(get_energy(P_1_QK_results), get_energy(P_1_SM_results))
AV_SM_energy = max(get_energy(P_1_AV_results), get_energy(P_1_SM_results))
AV_ACC_energy = max(get_energy(P_1_AV_results), get_energy(P_1_ACC_results))
QK_ACC_energy = max(get_energy(P_1_QK_results), get_energy(P_1_ACC_results))
ACC_energy = get_energy(P_1_ACC_results)

P_2_energy = QK_energy+4*QK_SM_energy+4*AV_SM_energy+4*AV_ACC_energy+3*QK_ACC_energy+ACC_energy

print("Total Pipeline Energy: ", P_2_energy)
# Out:
# Total Pipeline Energy:  0.017601003227433624

# %% [markdown]
# # P = 3

# %%
# Total Pipeline Cycles
P_3_cycles = QK_cycles+5*QK_SM_cycles+3*AV_SM_cycles+5*AV_ACC_cycles+2*QK_ACC_cycles+ACC_cycles

print("Total Pipeline Cycles: ", P_3_cycles)
# Out:
# Total Pipeline Cycles:  0.00044115570536007453

# %%
# Total Pipeline Cycles
P_3_energy = QK_energy+5*QK_SM_energy+3*AV_SM_energy+5*AV_ACC_energy+2*QK_ACC_energy+ACC_energy

print("Total Pipeline Energy: ", P_3_energy)
# Out:
# Total Pipeline Energy:  0.017601003227433624
