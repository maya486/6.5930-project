# %%
from accelforge import Spec, examples
from pathlib import Path

# %% [markdown]
# # Baseline from Mapper

# %%
# Load architecture, workload, and mapping
spec_mapper_baseline = Spec.from_yaml(
    examples.arches.tpu_v4i,
    examples.workloads.gpt3_175B,
    # "../mappings/manual_baseline.yaml"
    "../mappings/mapper_generated_clean.yaml"
)
# Run analysis
results = spec_mapper_baseline.evaluate_mapping()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 9
#       5     # "../mappings/manual_baseline.yaml"
#       6     "../mappings/mapper_generated_clean.yaml"
#       7 )
#       8 # Run analysis
# ----> 9 results = spec_mapper_baseline.evaluate_mapping()
#
# File ~/6.5930/accelforge/accelforge/frontend/spec.py:351, in Spec.evaluate_mapping(self)
#     346 """
#     347 Evaluate the mapping in the spec.
#     348 """
#     349 from accelforge.model import evaluate_mapping
# --> 351 return evaluate_mapping(self)
#
# File ~/6.5930/accelforge/accelforge/model/main.py:206, in evaluate_mapping(spec, flattened_arches, evaluated_specs)
#     199 # Restore the original order
#     200 einsum2pmappings = {
#     201     einsum_name: einsum2pmappings[einsum_name]
#     202     for einsum_name in spec.workload.einsum_names
#     203     if einsum_name in einsum2pmappings
#     204 }
# --> 206 return clean_compress_and_join_pmappings(
#     207     pmappings=MultiEinsumPmappings(
#     208         spec=spec,
#     209         einsum2pmappings=einsum2pmappings,
#     210         pmapping_objects=pmapping_objects,
#     211         einsum2jobs=einsum2jobs,
#     212         can_combine_multiple_runs=False,
#     213         einsums_with_pmappings_generated=oset(spec.workload.einsum_names),
#     214         flattened_arches=flattened_arches,
#     215         evaluated_specs=evaluated_specs,
#     216     ),
#     217     metrics=spec.model.metrics,
#     218     print_progress=False,
#     219     for_model=True,
#     220 )
#
# File ~/6.5930/accelforge/accelforge/mapper/FFM/_join_pmappings/join_pmappings.py:332, in clean_compress_and_join_pmappings(pmappings, metrics, for_model, require_all_einsums, _pmapping_row_filter_function, print_progress)
#     326 _check_einsum2pmappings_not_empty(einsum2pmappings, pmappings)
#     328 compressed, decompress_data = compress_einsum2pmappings(
#     329     einsum2pmappings, print_progress
#     330 )
# --> 332 joined = multi_strategy_join(
#     333     pmappings.spec,
#     334     compressed,
#     335     print_progress,
#     336     metrics,
#     337     for_model,
#     338     _pmapping_row_filter_function,
#     339 )
#     341 joined = decompress_pmappings(joined, decompress_data)
#     343 for einsum_name in einsum2pmappings:
#
# File ~/6.5930/accelforge/accelforge/mapper/FFM/_join_pmappings/join_pmappings.py:260, in multi_strategy_join(spec, compressed, print_progress, metrics, for_model, _pmapping_row_filter_function)
#     258 # If it's for the model, just join things directly
#     259 if for_model:
# --> 260     return join_pmappings(
#     261         deepcopy(compressed),
#     262         spec,
#     263         print_progress=print_progress,
#     264         metrics=metrics,
#     265         _pmapping_row_filter_function=_pmapping_row_filter_function,
#     266     )
#     268 if metrics & Metrics.RESOURCE_USAGE:
#     269     return join_strategy_2(
#     270         spec,
#     271         compressed,
#    (...)    275         _pmapping_row_filter_function,
#     276     )
#
# File ~/6.5930/accelforge/accelforge/mapper/FFM/_join_pmappings/join_pmappings.py:766, in join_pmappings(pmapping_groups, spec, lookahead_filter, metrics, _pmapping_row_filter_function, print_progress)
#     761     continue
#     763 t0 = time.time()
#     765 combined.append(
# --> 766     a.merge_next(
#     767         b,
#     768         live_tensors,
#     769         live_tensors_with_right,
#     770         aliased_tensors,
#     771         compatibility_joined=compatibility_joined,
#     772         permuted_compatibility_left=compatibility_a,
#     773         permuted_compatibility_right=compatibility_b,
#     774         delay=DELAY,
#     775         _pmapping_row_filter_function=_pmapping_row_filter_function,
#     776         ignored_resources=ignored_resources,
#     777     )
#     778 )
#     780 if not DELAY:
#     781     cur_nmappings += len(a.mappings.data) * len(b.mappings.data)
#
# File ~/6.5930/accelforge/accelforge/mapper/FFM/_join_pmappings/pmapping_group.py:78, in PmappingGroup.merge_next(self, right, live_tensors_post_join, live_tensors_with_right, aliased_tensors, compatibility_joined, ignored_resources, permuted_compatibility_left, permuted_compatibility_right, delay, _pmapping_row_filter_function, _force_allow_invalid_only_for_runtime_test, _is_invalid)
#      71 assert (
#      72     shared_loop_index == self.compatibility.n_loops - 1
#      73 ), "shared loop index not equal to left pmapping n_loops - 1"
#      74 next_shared_loop_index = compatibility_joined.shared_loop_index(
#      75     live_tensors_post_join
#      76 )
#      77 assert (
# ---> 78     next_shared_loop_index == compatibility_joined.n_loops - 1
#      79 ), "next shared loop index not equal to joined pmapping n_loops - 1"
#      80 assert compatibility_joined.tensor_names.issubset(
#      81     live_tensors_post_join
#      82 ), "joined compatibility includes tensors not live after joining"
#      84 still_live_reservations = [
#      85     r
#      86     for r in self.compatibility.tensors
#      87     if r.name in live_tensors_post_join
#      88     and r.name not in right.compatibility.tensor_names
#      89 ]
#
# AssertionError: next shared loop index not equal to joined pmapping n_loops - 1
